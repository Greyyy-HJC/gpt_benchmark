# %%
import numpy as np
import gvar as gv
from lametlat.utils.plot_settings import *
from lametlat.utils.resampling import *
from lametlat.preprocess.read_raw import pt2_to_meff

# %%
# corr_conf_ls = gv.load("dump/quark_prop_conf_ls_gfix_hyp.dat")
corr_conf_ls = gv.load("dump/quark_prop_conf_ls_gfix_hyp_gfix.dat")
# corr_conf_ls = gv.load("dump/quark_prop_conf_ls_no_cg.dat")
print(np.shape(corr_conf_ls))

corr_jk = jackknife(corr_conf_ls)
corr_gv = jk_ls_avg(corr_jk)

meff = pt2_to_meff(corr_gv, boundary="none")

fig, ax = default_plot()
ax.errorbar(np.arange(len(meff)), gv.mean(meff), gv.sdev(meff), label="meff", **errorb)
ax.set_xlabel(r"$t$", **fs_p)
ax.set_ylabel(r"$m_{\mathrm{eff}}$", **fs_p)
ax.legend(**fs_small_p)
# ax.set_ylim(-2, 2.2)
plt.tight_layout()
plt.show()
# Out:
# (10, 16)

# %%
corr_conf_ls = gv.load("dump/quark_prop_conf_ls_gfix_hyp.dat")
# corr_conf_ls = gv.load("dump/quark_prop_conf_ls_gfix_hyp_gfix.dat")
# corr_conf_ls = gv.load("dump/quark_prop_conf_ls_no_cg.dat")
print(np.shape(corr_conf_ls))

corr_jk = jackknife(corr_conf_ls)
corr_gv = jk_ls_avg(corr_jk)

meff = pt2_to_meff(corr_gv, boundary="none")

fig, ax = default_plot()
ax.errorbar(np.arange(len(meff)), gv.mean(meff), gv.sdev(meff), label="meff", **errorb)
ax.set_xlabel(r"$t$", **fs_p)
ax.set_ylabel(r"$m_{\mathrm{eff}}$", **fs_p)
ax.legend(**fs_small_p)
# ax.set_ylim(-2, 2.2)
plt.tight_layout()
plt.show()
# Out:
# (10, 16)

# %%
# corr_conf_ls = gv.load("dump/quark_prop_conf_ls_gfix_hyp.dat")
# corr_conf_ls = gv.load("dump/quark_prop_conf_ls_gfix_hyp_gfix.dat")
corr_conf_ls = gv.load("dump/quark_prop_conf_ls_no_cg.dat")
print(np.shape(corr_conf_ls))

corr_jk = jackknife(corr_conf_ls)
corr_gv = jk_ls_avg(corr_jk)

meff = pt2_to_meff(corr_gv, boundary="none")

fig, ax = default_plot()
ax.errorbar(np.arange(len(meff)), gv.mean(meff), gv.sdev(meff), label="meff", **errorb)
ax.set_xlabel(r"$t$", **fs_p)
ax.set_ylabel(r"$m_{\mathrm{eff}}$", **fs_p)
ax.legend(**fs_small_p)
# ax.set_ylim(-2, 2.2)
plt.tight_layout()
plt.show()
# Out:
# (50, 16)
# /home/jinchen/git/package/LaMETLat/lametlat/preprocess/read_raw.py:76: RuntimeWarning: invalid value encountered in log
#   meff_array = np.log(pt2_array[:-1] / pt2_array[1:])
